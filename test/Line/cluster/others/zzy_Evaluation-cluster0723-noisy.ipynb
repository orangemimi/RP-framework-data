# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from itertools import combinations
import warnings 
warnings.filterwarnings("ignore")

# 生成示例数据
df = pd.read_csv("./repro-out/pred_nonoisy_1000.csv")

out0 = df["Out0"]=df["cluster"]=pd.read_csv("pred_nonoisy_initial.csv")
x= df.index
data = df.copy()

# %%
# 定义属性模板
attributes_template = ["value"]
results_df = pd.DataFrame()
# 计算特定聚类的质心的函数
def calculate_centroids_with_attrs(data, clustering_col, attributes):
    centroids = {}
    for cluster_id in range(4):
        cluster_data = data[data[clustering_col] == cluster_id]
        centroid = cluster_data[attributes].mean()
        centroids[cluster_id] = centroid
    return centroids

def calculate_row(data, cluster_col, attributes, row_name, df):
    centroids = calculate_centroids_with_attrs(data, cluster_col, attributes)
    
    # 提取质心值并构建一个数据框
    centroids_df = pd.DataFrame(centroids).T
    centroids_df.columns = ['value']
    
    # 按照Rooftop_area进行排序
    centroids_df = centroids_df.sort_values(by='value')
    print("centroids_df", centroids_df)
    # 重新分配新的聚类标签
    sorted_clusters = centroids_df.index.tolist()
    print("sorted_clusters", sorted_clusters)
    cluster_mapping = {original_cluster: new_cluster for new_cluster, original_cluster in enumerate(sorted_clusters, start=1)}
    print("cluster_mapping", cluster_mapping)
    data[f'new_{cluster_col}'] = data[cluster_col].map(cluster_mapping)
    
    # 重新计算新的聚类质心
    new_centroids = calculate_centroids_with_attrs(data, f'new_{cluster_col}', attributes)
    new_centroids_df = pd.DataFrame(new_centroids).T
    new_centroids_df.columns = ['value']
    
    # 检查空值
    print(f"new_{cluster_col} column null values:", data[f'new_{cluster_col}'].isnull().sum())
    print(f"new_centroids_df null values:", new_centroids_df['value'].isnull().sum())
    
    # 将排序后的结果添加到结果数据框中
    df[row_name] = list(new_centroids_df['value'])

    return data, df

# 计算每个复现聚类结果的质心
for i in range(1001):
    # print(i)
    cluster_col = f'Out{i}'
    attributes = attributes_template
    data_repro, results_df = calculate_row(data, cluster_col, attributes, f'Out{i}', results_df)

# data.to_csv('repro-out/filtered_data.csv')
print(data_repro)
data_repro.to_csv('repro-out/filtered_data.csv')
# Out:
# centroids_df       value
# 3 -1.435644
# 0 -0.636386
# 1  0.176969
# 2  1.040204
# sorted_clusters [3, 0, 1, 2]
# cluster_mapping {3: 1, 0: 2, 1: 3, 2: 4}
# new_Out0 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.400581
# 3 -0.618670
# 0  0.163641
# 2  1.017596
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out1 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.416009
# 2 -0.635113
# 3  0.146429
# 0  1.008766
# sorted_clusters [1, 2, 3, 0]
# cluster_mapping {1: 1, 2: 2, 3: 3, 0: 4}
# new_Out2 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out3 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out4 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.435644
# 0 -0.636386
# 1  0.179594
# 3  1.044926
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out5 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.621957
# 0  0.158574
# 2  1.013159
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out6 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out7 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out8 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.391627
# 0 -0.612099
# 1  0.182003
# 3  1.044926
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out9 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [0, 2, 3, 1]
# cluster_mapping {0: 1, 2: 2, 3: 3, 1: 4}
# new_Out10 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out11 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 1  0.008349
# 2  0.934080
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out12 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out13 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out14 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out15 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.176750
# 3  1.035530
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out16 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.752396
# 2  0.017304
# 0  0.942123
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out17 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out18 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.497156
# 0 -0.740448
# 2  0.033288
# 1  0.958541
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out19 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out20 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out21 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 1 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [0, 1, 3, 2]
# cluster_mapping {0: 1, 1: 2, 3: 3, 2: 4}
# new_Out22 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out23 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.438935
# 3 -0.654747
# 0  0.134871
# 2  1.008766
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out24 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out25 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 0 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [1, 0, 3, 2]
# cluster_mapping {1: 1, 0: 2, 3: 3, 2: 4}
# new_Out26 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.489891
# 1 -0.738742
# 0  0.018962
# 2  0.938082
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out27 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out28 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.452175
# 0 -0.693486
# 1  0.064061
# 3  0.962722
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out29 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out30 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out31 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.438935
# 1 -0.654747
# 3  0.134871
# 0  1.008766
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out32 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out33 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 2 -0.755836
# 3  0.008349
# 0  0.934080
# sorted_clusters [1, 2, 3, 0]
# cluster_mapping {1: 1, 2: 2, 3: 3, 0: 4}
# new_Out34 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out35 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.497156
# 3 -0.740448
# 1  0.033288
# 2  0.958541
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out36 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.452175
# 0 -0.693486
# 3  0.064061
# 1  0.962722
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out37 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out38 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 2 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [3, 2, 0, 1]
# cluster_mapping {3: 1, 2: 2, 0: 3, 1: 4}
# new_Out39 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out40 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 1 -0.724976
# 0  0.033288
# 3  0.958541
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out41 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [0, 2, 3, 1]
# cluster_mapping {0: 1, 2: 2, 3: 3, 1: 4}
# new_Out42 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.397578
# 0 -0.615363
# 1  0.182003
# 3  1.044926
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out43 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.391627
# 0 -0.612099
# 3  0.182003
# 1  1.044926
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out44 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out45 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out46 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.486312
# 1 -0.735305
# 3  0.033288
# 0  0.958541
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out47 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.391627
# 2 -0.612099
# 1  0.182003
# 3  1.044926
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out48 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.465630
# 3 -0.724976
# 0  0.023453
# 2  0.942123
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out49 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out50 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out51 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out52 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out53 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.752396
# 2  0.017304
# 0  0.942123
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out54 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.465630
# 2 -0.724976
# 3  0.023453
# 0  0.942123
# sorted_clusters [1, 2, 3, 0]
# cluster_mapping {1: 1, 2: 2, 3: 3, 0: 4}
# new_Out55 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 2 -0.755836
# 1  0.008349
# 3  0.934080
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out56 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out57 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.397578
# 0 -0.615363
# 3  0.182003
# 1  1.044926
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out58 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.475802
# 2 -0.730152
# 3  0.023453
# 0  0.942123
# sorted_clusters [1, 2, 3, 0]
# cluster_mapping {1: 1, 2: 2, 3: 3, 0: 4}
# new_Out59 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out60 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out61 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.493497
# 3 -0.740461
# 0  0.021414
# 2  0.942123
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out62 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.406655
# 3 -0.621935
# 1  0.163641
# 2  1.017596
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out63 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.486312
# 1 -0.737028
# 3  0.021414
# 0  0.942123
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out64 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.465630
# 0 -0.724976
# 1  0.033288
# 2  0.958541
# sorted_clusters [3, 0, 1, 2]
# cluster_mapping {3: 1, 0: 2, 1: 3, 2: 4}
# new_Out65 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out66 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out67 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.452175
# 0 -0.693486
# 2  0.064061
# 1  0.962722
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out68 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 2 -0.724976
# 1  0.033288
# 3  0.958541
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out69 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out70 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out71 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.400581
# 3 -0.618670
# 1  0.163641
# 2  1.017596
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out72 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.400581
# 2 -0.618670
# 0  0.163641
# 3  1.017596
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out73 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out74 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.452175
# 0 -0.693486
# 3  0.064061
# 1  0.962722
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out75 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 2 -0.755836
# 1  0.008349
# 3  0.934080
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out76 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.465630
# 0 -0.724976
# 1  0.033288
# 2  0.958541
# sorted_clusters [3, 0, 1, 2]
# cluster_mapping {3: 1, 0: 2, 1: 3, 2: 4}
# new_Out77 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 0 -0.724976
# 1  0.033288
# 3  0.958541
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out78 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 3 -0.724976
# 2  0.023453
# 1  0.942123
# sorted_clusters [0, 3, 2, 1]
# cluster_mapping {0: 1, 3: 2, 2: 3, 1: 4}
# new_Out79 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 3 -0.618631
# 1  0.171427
# 2  1.026432
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out80 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out81 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out82 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.435644
# 0 -0.636386
# 2  0.176969
# 1  1.040204
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out83 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out84 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [0, 3, 2, 1]
# cluster_mapping {0: 1, 3: 2, 2: 3, 1: 4}
# new_Out85 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 0 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [1, 0, 3, 2]
# cluster_mapping {1: 1, 0: 2, 3: 3, 2: 4}
# new_Out86 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.438935
# 0 -0.654747
# 1  0.134871
# 3  1.008766
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out87 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 1 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [0, 1, 3, 2]
# cluster_mapping {0: 1, 1: 2, 3: 3, 2: 4}
# new_Out88 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.391627
# 1 -0.612099
# 3  0.182003
# 0  1.044926
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out89 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.504633
# 1 -0.745574
# 0  0.031240
# 3  0.958541
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out90 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.497156
# 0 -0.740448
# 1  0.033288
# 3  0.958541
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out91 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.455489
# 1 -0.705598
# 0  0.051637
# 3  0.962722
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out92 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out93 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.489891
# 3 -0.738742
# 0  0.018962
# 2  0.938082
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out94 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out95 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 3 -0.618631
# 1  0.171427
# 2  1.026432
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out96 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 1 -0.755836
# 0  0.010799
# 3  0.938082
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out97 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 2 -0.755836
# 1  0.008349
# 3  0.934080
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out98 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.465630
# 0 -0.724976
# 2  0.023453
# 1  0.942123
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out99 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out100 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.452175
# 0 -0.693486
# 3  0.064061
# 1  0.962722
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out101 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 1 -0.724976
# 3  0.033288
# 0  0.958541
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out102 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out103 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.455489
# 2 -0.705598
# 1  0.051637
# 3  0.962722
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out104 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.435644
# 2 -0.638037
# 0  0.171916
# 3  1.035530
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out105 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.452175
# 1 -0.693486
# 0  0.064061
# 2  0.962722
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out106 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.435644
# 2 -0.636386
# 1  0.176969
# 3  1.040204
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out107 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.475802
# 3 -0.730152
# 2  0.023453
# 0  0.942123
# sorted_clusters [1, 3, 2, 0]
# cluster_mapping {1: 1, 3: 2, 2: 3, 0: 4}
# new_Out108 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.438935
# 3 -0.654747
# 2  0.134871
# 0  1.008766
# sorted_clusters [1, 3, 2, 0]
# cluster_mapping {1: 1, 3: 2, 2: 3, 0: 4}
# new_Out109 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out110 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out111 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.435644
# 2 -0.636386
# 1  0.176969
# 3  1.040204
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out112 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.403605
# 0 -0.618631
# 2  0.171427
# 1  1.026432
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out113 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.504633
# 0 -0.745574
# 1  0.031240
# 2  0.958541
# sorted_clusters [3, 0, 1, 2]
# cluster_mapping {3: 1, 0: 2, 1: 3, 2: 4}
# new_Out114 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.621957
# 3  0.158574
# 0  1.013159
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out115 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.621957
# 3  0.158574
# 1  1.013159
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out116 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out117 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.391627
# 2 -0.612099
# 1  0.182003
# 3  1.044926
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out118 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out119 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out120 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out121 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.475802
# 0 -0.730152
# 3  0.023453
# 1  0.942123
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out122 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out123 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 2 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [3, 2, 0, 1]
# cluster_mapping {3: 1, 2: 2, 0: 3, 1: 4}
# new_Out124 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out125 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 3 -0.724976
# 1  0.023453
# 2  0.942123
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out126 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out127 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.438935
# 1 -0.654747
# 3  0.134871
# 0  1.008766
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out128 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 1 -0.724976
# 3  0.023453
# 0  0.942123
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out129 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out130 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 2 -0.724976
# 1  0.023453
# 3  0.942123
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out131 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.465630
# 3 -0.724976
# 0  0.023453
# 2  0.942123
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out132 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out133 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [0, 3, 2, 1]
# cluster_mapping {0: 1, 3: 2, 2: 3, 1: 4}
# new_Out134 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out135 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out136 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out137 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out138 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out139 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 3 -0.621957
# 2  0.158574
# 1  1.013159
# sorted_clusters [0, 3, 2, 1]
# cluster_mapping {0: 1, 3: 2, 2: 3, 1: 4}
# new_Out140 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out141 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.621957
# 0  0.158574
# 2  1.013159
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out142 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.497156
# 1 -0.740448
# 3  0.033288
# 0  0.958541
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out143 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out144 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out145 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.620304
# 3  0.163641
# 1  1.017596
# sorted_clusters [0, 2, 3, 1]
# cluster_mapping {0: 1, 2: 2, 3: 3, 1: 4}
# new_Out146 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.452175
# 3 -0.696925
# 1  0.059861
# 2  0.962722
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out147 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out148 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.403605
# 1 -0.618631
# 2  0.171427
# 0  1.026432
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out149 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 1 -0.724976
# 0  0.033288
# 3  0.958541
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out150 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out151 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out152 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out153 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out154 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.419217
# 1 -0.626718
# 2  0.179378
# 0  1.040204
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out155 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 3 -0.618631
# 1  0.171427
# 2  1.026432
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out156 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out157 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [1, 2, 3, 0]
# cluster_mapping {1: 1, 2: 2, 3: 3, 0: 4}
# new_Out158 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.400581
# 3 -0.618670
# 0  0.163641
# 2  1.017596
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out159 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 0 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [1, 0, 3, 2]
# cluster_mapping {1: 1, 0: 2, 3: 3, 2: 4}
# new_Out160 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [0, 2, 3, 1]
# cluster_mapping {0: 1, 2: 2, 3: 3, 1: 4}
# new_Out161 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 3 -0.618631
# 1  0.171427
# 2  1.026432
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out162 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out163 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.400581
# 2 -0.616997
# 0  0.176750
# 3  1.035530
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out164 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out165 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.391627
# 2 -0.612099
# 3  0.182003
# 1  1.044926
# sorted_clusters [0, 2, 3, 1]
# cluster_mapping {0: 1, 2: 2, 3: 3, 1: 4}
# new_Out166 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out167 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.508416
# 0 -0.754134
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out168 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out169 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out170 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.435644
# 0 -0.638037
# 1  0.171916
# 3  1.035530
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out171 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.452175
# 0 -0.693486
# 3  0.064061
# 1  0.962722
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out172 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.176750
# 3  1.035530
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out173 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 3 -0.620304
# 1  0.163641
# 2  1.017596
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out174 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.452175
# 0 -0.693486
# 3  0.064061
# 1  0.962722
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out175 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out176 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.435644
# 0 -0.636386
# 1  0.179594
# 3  1.044926
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out177 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.400581
# 0 -0.618670
# 3  0.163641
# 1  1.017596
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out178 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.452175
# 0 -0.693486
# 2  0.064061
# 1  0.962722
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out179 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.497156
# 3 -0.740448
# 0  0.033288
# 2  0.958541
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out180 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 3 -0.724976
# 1  0.023453
# 2  0.942123
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out181 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 3 -0.724976
# 1  0.033288
# 2  0.958541
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out182 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 1 -0.755836
# 3  0.008349
# 0  0.934080
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out183 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out184 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 2 -0.754112
# 0  0.015267
# 3  0.942123
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out185 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out186 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.438935
# 1 -0.654747
# 0  0.134871
# 3  1.008766
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out187 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.397578
# 1 -0.615363
# 0  0.179378
# 3  1.040204
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out188 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out189 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.455489
# 0 -0.705598
# 1  0.051637
# 3  0.962722
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out190 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out191 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out192 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.397578
# 0 -0.615363
# 3  0.182003
# 1  1.044926
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out193 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.438935
# 1 -0.656397
# 0  0.132537
# 2  1.008766
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out194 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out195 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.397578
# 2 -0.615363
# 1  0.182003
# 3  1.044926
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out196 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out197 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out198 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.752396
# 2  0.017304
# 0  0.942123
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out199 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.438935
# 2 -0.654747
# 0  0.134871
# 3  1.008766
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out200 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [1, 2, 3, 0]
# cluster_mapping {1: 1, 2: 2, 3: 3, 0: 4}
# new_Out201 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 1 -0.724976
# 0  0.033288
# 3  0.958541
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out202 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 0 -0.724976
# 3  0.023453
# 1  0.942123
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out203 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 2  0.171427
# 0  1.026432
# sorted_clusters [1, 3, 2, 0]
# cluster_mapping {1: 1, 3: 2, 2: 3, 0: 4}
# new_Out204 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out205 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out206 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out207 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.452175
# 1 -0.693486
# 2  0.064061
# 3  0.962722
# sorted_clusters [0, 1, 2, 3]
# cluster_mapping {0: 1, 1: 2, 2: 3, 3: 4}
# new_Out208 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.752396
# 1  0.017304
# 2  0.942123
# sorted_clusters [3, 0, 1, 2]
# cluster_mapping {3: 1, 0: 2, 1: 3, 2: 4}
# new_Out209 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.438935
# 3 -0.661388
# 0  0.120452
# 2  0.999966
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out210 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.010799
# 0  0.938082
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out211 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [1, 3, 2, 0]
# cluster_mapping {1: 1, 3: 2, 2: 3, 0: 4}
# new_Out212 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out213 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 0 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [1, 0, 3, 2]
# cluster_mapping {1: 1, 0: 2, 3: 3, 2: 4}
# new_Out214 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out215 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.010799
# 1  0.938082
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out216 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.452175
# 3 -0.693486
# 0  0.064061
# 2  0.962722
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out217 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out218 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out219 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 1 -0.755836
# 3  0.008349
# 0  0.934080
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out220 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.452175
# 0 -0.693486
# 2  0.064061
# 1  0.962722
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out221 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.442207
# 1 -0.663046
# 0  0.112581
# 2  0.987186
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out222 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 1 -0.755836
# 3  0.008349
# 0  0.934080
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out223 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.435644
# 0 -0.638037
# 1  0.171916
# 3  1.035530
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out224 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.400581
# 2 -0.618670
# 3  0.163641
# 1  1.017596
# sorted_clusters [0, 2, 3, 1]
# cluster_mapping {0: 1, 2: 2, 3: 3, 1: 4}
# new_Out225 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.752396
# 2  0.017304
# 0  0.942123
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out226 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 2 -0.755836
# 1  0.008349
# 3  0.934080
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out227 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.438935
# 3 -0.654747
# 1  0.134871
# 2  1.008766
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out228 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 2  0.171427
# 0  1.026432
# sorted_clusters [1, 3, 2, 0]
# cluster_mapping {1: 1, 3: 2, 2: 3, 0: 4}
# new_Out229 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.452175
# 3 -0.696925
# 0  0.059861
# 2  0.962722
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out230 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 0 -0.618631
# 3  0.171427
# ...
# 1 -0.618631
# 3  0.171427
# 0  1.026432
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out936 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out937 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 3 -0.618631
# 1  0.171427
# 2  1.026432
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out938 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 2  0.171427
# 0  1.026432
# sorted_clusters [1, 3, 2, 0]
# cluster_mapping {1: 1, 3: 2, 2: 3, 0: 4}
# new_Out939 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.486312
# 3 -0.737028
# 2  0.021414
# 1  0.942123
# sorted_clusters [0, 3, 2, 1]
# cluster_mapping {0: 1, 3: 2, 2: 3, 1: 4}
# new_Out940 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.475802
# 0 -0.730152
# 3  0.033288
# 1  0.958541
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out941 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 2 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [3, 2, 0, 1]
# cluster_mapping {3: 1, 2: 2, 0: 3, 1: 4}
# new_Out942 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out943 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.400581
# 0 -0.618670
# 3  0.163641
# 1  1.017596
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out944 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.504633
# 2 -0.745574
# 0  0.031240
# 3  0.958541
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out945 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [3, 1, 0, 2]
# cluster_mapping {3: 1, 1: 2, 0: 3, 2: 4}
# new_Out946 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out947 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.465630
# 0 -0.724976
# 1  0.033288
# 3  0.958541
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out948 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out949 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out950 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out951 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.497156
# 3 -0.743877
# 0  0.014451
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out952 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out953 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 1  0.008349
# 0  0.934080
# sorted_clusters [2, 3, 1, 0]
# cluster_mapping {2: 1, 3: 2, 1: 3, 0: 4}
# new_Out954 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.452175
# 0 -0.693486
# 3  0.064061
# 1  0.962722
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out955 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 2 -0.755836
# 0  0.008349
# 3  0.934080
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out956 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out957 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 3 -0.724976
# 2  0.023453
# 1  0.942123
# sorted_clusters [0, 3, 2, 1]
# cluster_mapping {0: 1, 3: 2, 2: 3, 1: 4}
# new_Out958 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 0 -0.755836
# 3  0.008349
# 1  0.934080
# sorted_clusters [2, 0, 3, 1]
# cluster_mapping {2: 1, 0: 2, 3: 3, 1: 4}
# new_Out959 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.438935
# 0 -0.654747
# 2  0.134871
# 1  1.008766
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out960 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 1  0.171427
# 3  1.026432
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out961 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out962 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 0 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [3, 0, 2, 1]
# cluster_mapping {3: 1, 0: 2, 2: 3, 1: 4}
# new_Out963 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 1  0.008349
# 2  0.934080
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out964 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.438935
# 3 -0.654747
# 1  0.134871
# 2  1.008766
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out965 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.452175
# 3 -0.696925
# 0  0.059861
# 2  0.962722
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out966 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.409728
# 0 -0.621893
# 1  0.179378
# 3  1.040204
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out967 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 1  0.008349
# 2  0.934080
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out968 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 0 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [1, 0, 3, 2]
# cluster_mapping {1: 1, 0: 2, 3: 3, 2: 4}
# new_Out969 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.465630
# 3 -0.724976
# 1  0.033288
# 2  0.958541
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out970 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out971 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.397578
# 1 -0.615363
# 3  0.182003
# 0  1.044926
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out972 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.403605
# 1 -0.621957
# 3  0.158574
# 0  1.013159
# sorted_clusters [2, 1, 3, 0]
# cluster_mapping {2: 1, 1: 2, 3: 3, 0: 4}
# new_Out973 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.409728
# 1 -0.621893
# 0  0.182003
# 3  1.044926
# sorted_clusters [2, 1, 0, 3]
# cluster_mapping {2: 1, 1: 2, 0: 3, 3: 4}
# new_Out974 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out975 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out976 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.403605
# 2 -0.618631
# 3  0.171427
# 1  1.026432
# sorted_clusters [0, 2, 3, 1]
# cluster_mapping {0: 1, 2: 2, 3: 3, 1: 4}
# new_Out977 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 2  0.008349
# 1  0.934080
# sorted_clusters [0, 3, 2, 1]
# cluster_mapping {0: 1, 3: 2, 2: 3, 1: 4}
# new_Out978 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.504633
# 0 -0.745574
# 1  0.031240
# 3  0.958541
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out979 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.452175
# 2 -0.693486
# 1  0.064061
# 3  0.962722
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out980 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.391627
# 0 -0.612099
# 1  0.182003
# 3  1.044926
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out981 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out982 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out983 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 2  0.171427
# 0  1.026432
# sorted_clusters [1, 3, 2, 0]
# cluster_mapping {1: 1, 3: 2, 2: 3, 0: 4}
# new_Out984 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 3 -0.618631
# 0  0.171427
# 2  1.026432
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out985 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out986 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 1  0.008349
# 2  0.934080
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out987 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 2 -0.755836
# 1  0.008349
# 3  0.934080
# sorted_clusters [0, 2, 1, 3]
# cluster_mapping {0: 1, 2: 2, 1: 3, 3: 4}
# new_Out988 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out989 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 1 -0.755836
# 2  0.008349
# 0  0.934080
# sorted_clusters [3, 1, 2, 0]
# cluster_mapping {3: 1, 1: 2, 2: 3, 0: 4}
# new_Out990 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.465630
# 2 -0.724976
# 3  0.023453
# 0  0.942123
# sorted_clusters [1, 2, 3, 0]
# cluster_mapping {1: 1, 2: 2, 3: 3, 0: 4}
# new_Out991 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out992 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.512257
# 3 -0.755836
# 0  0.008349
# 2  0.934080
# sorted_clusters [1, 3, 0, 2]
# cluster_mapping {1: 1, 3: 2, 0: 3, 2: 4}
# new_Out993 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 3 -1.512257
# 2 -0.755836
# 1  0.008349
# 0  0.934080
# sorted_clusters [3, 2, 1, 0]
# cluster_mapping {3: 1, 2: 2, 1: 3, 0: 4}
# new_Out994 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 0 -0.618631
# 3  0.171427
# 2  1.026432
# sorted_clusters [1, 0, 3, 2]
# cluster_mapping {1: 1, 0: 2, 3: 3, 2: 4}
# new_Out995 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.512257
# 3 -0.755836
# 0  0.008349
# 1  0.934080
# sorted_clusters [2, 3, 0, 1]
# cluster_mapping {2: 1, 3: 2, 0: 3, 1: 4}
# new_Out996 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 2 -1.438935
# 0 -0.654747
# 1  0.134871
# 3  1.008766
# sorted_clusters [2, 0, 1, 3]
# cluster_mapping {2: 1, 0: 2, 1: 3, 3: 4}
# new_Out997 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 1  0.008349
# 2  0.934080
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out998 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 1 -1.403605
# 2 -0.618631
# 0  0.171427
# 3  1.026432
# sorted_clusters [1, 2, 0, 3]
# cluster_mapping {1: 1, 2: 2, 0: 3, 3: 4}
# new_Out999 column null values: 0
# new_centroids_df null values: 1
# centroids_df       value
# 0 -1.512257
# 3 -0.755836
# 1  0.008349
# 2  0.934080
# sorted_clusters [0, 3, 1, 2]
# cluster_mapping {0: 1, 3: 2, 1: 3, 2: 4}
# new_Out1000 column null values: 0
# new_centroids_df null values: 1
#      Out1  Out2  Out3  Out4  Out5  Out6  Out7  Out8  Out9  Out10  ...  \
# 0       0     3     1     1     1     0     0     2     1      3  ...
# 1       0     3     1     1     1     0     0     2     1      3  ...
# 2       0     3     1     1     1     0     0     2     1      3  ...
# 3       0     3     1     1     1     0     0     2     1      3  ...
# 4       0     3     1     1     1     0     0     2     1      3  ...
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 620     3     2     2     2     0     3     1     0     0      2  ...
# 621     0     3     1     1     1     0     0     2     1      3  ...
# 622     2     0     3     3     3     2     2     1     3      1  ...
# 623     2     0     3     3     3     2     2     1     3      1  ...
# 624     2     0     3     3     3     2     2     1     3      1  ...
#
#      new_Out991  new_Out992  new_Out993  new_Out994  new_Out995  new_Out996  \
# 0             3           3           3           3           3           3
# 1             3           3           3           3           3           3
# 2             3           3           3           3           3           3
# 3             3           3           3           3           3           3
# 4             3           3           3           3           3           3
# ..          ...         ...         ...         ...         ...         ...
# 620           2           2           2           2           2           2
# 621           3           3           3           3           3           3
# 622           4           4           4           4           4           4
# 623           4           4           4           4           4           4
# 624           4           4           4           4           4           4
#
#      new_Out997  new_Out998  new_Out999  new_Out1000
# 0             3           3           3            3
# 1             3           3           3            3
# 2             3           3           3            3
# 3             3           3           3            3
# 4             3           3           3            3
# ..          ...         ...         ...          ...
# 620           2           2           2            2
# 621           3           3           3            3
# 622           4           4           4            4
# 623           4           4           4            4
# 624           4           4           4            4
#
# [625 rows x 2004 columns]

# %%
# 筛选data_repro中包含新列的部分
filtered_data_repro = data[[f'new_Out{i}' for i in range(1, 1001)]]

# 计算每一行的cluster数及出现的频率
cluster_counts = filtered_data_repro.apply(pd.Series.value_counts, axis=1).fillna(0)
cluster_frequencies = cluster_counts.div(cluster_counts.sum(axis=1), axis=0)

# new_pred_cols = [f'new_pred{i}' for i in range(1, 1001)]
# filtered_data_repro['clusters_array'] = filtered_data_repro[new_pred_cols].apply(lambda row: row.unique(), axis=1)


filtered_data_repro.to_csv('repro-out/filtered_data_repro.csv')
# print(filtered_data_repro)

filtered_data_initial = data[[f'new_Out0']]
print(filtered_data_initial)
# Out:
#      new_Out0
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
# ..        ...
# 620         2
# 621         3
# 622         4
# 623         4
# 624         4
#
# [625 rows x 1 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('repro-out/filtered_data.csv')

relative_frequency=[]

# 创建频率分布图的函数
def plot_histogram(row_data, row_index):
    initial_value=filtered_data_initial.loc[row_index,:].values[0]
    unique, counts = np.unique(row_data, return_counts=True)
    frequencies = dict(zip(unique, counts))
    # print(frequencies)
    
    categories = [1, 2, 3, 4]
    frequency_values = [frequencies.get(category, 0) for category in categories]
    print(frequency_values)
    # 确定initial_value所在的类别及其频率
    initial_category = int(initial_value)
    initial_frequency = frequencies.get(initial_category, 0)
    relative_frequency.append(initial_frequency / len(row_data)) 
    # print(initial_relative_frequency)

    # plt.figure(figsize=(10, 6))
    # plt.bar(categories, frequency_values, tick_label=categories,alpha=0.3,label="Reproduced values")
    # plt.title(f'Frequency Distribution of Row {row_index} \n The probability of reproducbility is {initial_frequency / len(row_data) *100}%')
    # plt.axvline(x=initial_category, color='red', linestyle='dashed', linewidth=2, label=f'Initial value: {initial_value}')
    # plt.legend()
    # plt.xlabel('Category')
    # plt.ylabel('Frequency')
    # plt.ylim(0, max(frequency_values) + 10)  # Adjust ylim for better visualization
    # plt.show()

# 为每一行绘制直方图 filtered_data_repro.shape[0]
# print(filtered_data_repro.loc[0,:])
data2 = pd.read_csv('repro-out/filtered_data_repro.csv')
# filtered_data_repro= data2.iloc[:,1:1001]
# print(filtered_data_repro)
for i in range(1,filtered_data_repro.shape[0]):
    plot_histogram(filtered_data_repro.loc[i,:], i)

# 计算initial_relative_frequency数组的期望（均值）
expected_value = np.mean(relative_frequency)
print("Expected Value of Initial Relative Frequencies:", expected_value)
# Out:
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 661, 339, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 663, 337, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 442, 558]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 673, 327]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 442, 558, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 56, 944]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 585, 415]
# [0, 0, 0, 1000]
# [0, 0, 442, 558]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 509, 491, 0]
# [0, 478, 522, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 442, 558]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [509, 491, 0, 0]
# [348, 652, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 382, 618, 0]
# [0, 684, 316, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 393, 607, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 509, 491]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 388, 612]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [348, 652, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [393, 607, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 442, 558]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 432, 568, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 388, 612, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 509, 491, 0]
# [0, 0, 1000, 0]
# [0, 0, 442, 558]
# [0, 0, 335, 665]
# [0, 0, 374, 626]
# [0, 0, 585, 415]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [674, 326, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 442, 558, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 433, 567]
# [0, 0, 1000, 0]
# [0, 393, 607, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 490, 510, 0]
# [0, 509, 491, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [622, 378, 0, 0]
# [1000, 0, 0, 0]
# [609, 391, 0, 0]
# [0, 1000, 0, 0]
# [0, 435, 565, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 585, 415]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 509, 491, 0]
# [0, 0, 1000, 0]
# [0, 434, 566, 0]
# [341, 659, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 442, 558, 0]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [30, 970, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [338, 662, 0, 0]
# [348, 652, 0, 0]
# [50, 950, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [437, 563, 0, 0]
# [80, 920, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [348, 652, 0, 0]
# [490, 510, 0, 0]
# [441, 559, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 509, 491, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 486, 514, 0]
# [0, 1000, 0, 0]
# [584, 416, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 442, 558, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 490, 510, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 393, 607, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [509, 491, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 434, 566, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [341, 659, 0, 0]
# [597, 403, 0, 0]
# [597, 403, 0, 0]
# [583, 417, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [509, 491, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 385, 615, 0]
# [0, 0, 1000, 0]
# [0, 486, 514, 0]
# [0, 1000, 0, 0]
# [597, 403, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 291, 709, 0]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [442, 558, 0, 0]
# [617, 383, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [442, 558, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [670, 330, 0, 0]
# [348, 652, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 442, 558, 0]
# [0, 687, 313, 0]
# [0, 1000, 0, 0]
# [636, 364, 0, 0]
# [1000, 0, 0, 0]
# [583, 417, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [30, 970, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [347, 653, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [1000, 0, 0, 0]
# [330, 670, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 442, 558]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 393, 607, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 509, 491, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 618, 382, 0]
# [0, 509, 491, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [636, 364, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 388, 612, 0]
# [0, 0, 433, 567]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 442, 558, 0]
# [0, 354, 646, 0]
# [0, 0, 1000, 0]
# [0, 0, 586, 414]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 434, 566]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 336, 664]
# [0, 0, 0, 1000]
# [0, 0, 79, 921]
# [0, 478, 522, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 437, 563]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 688, 312]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 437, 563]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 101, 899]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 1000, 0]
# [0, 393, 607, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 509, 491, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 99, 901]
# [0, 0, 1000, 0]
# [0, 1000, 0, 0]
# [0, 1000, 0, 0]
# [0, 0, 1000, 0]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# [0, 0, 0, 1000]
# Expected Value of Initial Relative Frequencies: 0.9142179487179487

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#竖着的heat
# 创建一个矩阵来存储频率分布
frequency_matrix = np.zeros((filtered_data_repro.shape[0], 4))

# 填充频率矩阵
for i in range(filtered_data_repro.shape[0]):
    row_data = filtered_data_repro.loc[i, :]
    unique, counts = np.unique(row_data, return_counts=True)
    frequencies = dict(zip(unique, counts))
    for category in [1, 2, 3, 4]:
        frequency_matrix[i, category - 1] = frequencies.get(category, 0) / len(row_data)

# 创建一个矩阵来存储注释（只显示值大于0的标签）
annotations = np.where(frequency_matrix > 0, np.round(frequency_matrix, 2), '')


# 绘制热力图
plt.figure(figsize=(10, 30))
ax = sns.heatmap(frequency_matrix, annot=annotations, fmt="", xticklabels=[1, 2, 3, 4], yticklabels=False, cmap="viridis", cbar=True,
                 annot_kws={"size": 5, "ha": "center", "va": "center", "clip_on": True})
plt.title('Frequency Distribution Heatmap')
plt.xlabel('Category')
plt.ylabel('Rows')

# 调整标签的位置
for text in ax.texts:
    text.set_x(float(text.get_position()[0]) - 0.3)
    
# 添加表示filtered_data_initial的线
initial_values = filtered_data_initial['new_Out0'].values - 1  # 将值转换为索引
plt.plot(initial_values + 0.5, np.arange(0.5, filtered_data_repro.shape[0]+0.5), color='red', linewidth=2, label='Initial Value')  # +0.5 to center the line


# plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# 仅选择前20行的数据
number = filtered_data_repro.shape[0]//3
repro = filtered_data_repro.iloc[:number, :]
initial = filtered_data_initial.iloc[:number, :]
# repro = filtered_data_repro
# initial = filtered_data_initial

# 创建一个矩阵来存储频率分布
frequency_matrix = np.zeros((repro.shape[0], 4))

# 填充频率矩阵
for i in range(repro.shape[0]):
    row_data = repro.loc[i, :]
    unique, counts = np.unique(row_data, return_counts=True)
    frequencies = dict(zip(unique, counts))
    for category in [1, 2, 3, 4]:
        frequency_matrix[i, category - 1] = frequencies.get(category, 0) / len(row_data)

# 创建一个矩阵来存储注释（只显示值大于0的标签）
annotations = np.where(frequency_matrix > 0, np.round(frequency_matrix, 2), '')

# 绘制热力图
plt.figure(figsize=(30, 5))

ax = sns.heatmap(frequency_matrix.T, annot=annotations.T, fmt="", xticklabels=False, yticklabels=[1, 2, 3, 4], cmap="RdBu_r", cbar=True,
                 annot_kws={"size": 5, "ha": "center", "va": "center", "rotation": 90,"clip_on": True}) #cmap="viridis"

plt.title(f'Frequency Distribution Heatmap\n The reproducibility rate: {round(expected_value*100,4)}%')
plt.ylabel('Category')
plt.xlabel('Rows')

# 调整标签的位置
for text in ax.texts:
    text.set_y(float(text.get_position()[1]) + 0.3)

# 添加表示filtered_data_initial的线
initial_values = initial['new_Out0'].values - 1  # 将值转换为索引
plt.plot(np.arange(0.5, repro.shape[0] + 0.5), initial_values + 0.5, color='red', linewidth=1, label='Initial Value')
plt.savefig("repro-out/heatmap.svg")
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, cohen_kappa_score
from itertools import combinations
import scipy.stats as stats

# 设定随机种子以确保结果一致


# 计算置信区间
def calculate_confidence_interval(values, alpha=0.05):
    values = np.sort(values)
    lower_bound = np.percentile(values, alpha / 2 * 100)
    upper_bound = np.percentile(values, (1 - alpha / 2) * 100)
    return lower_bound, upper_bound

# 蒙特卡洛抽样并计算指定类型的统计量
def monteCarloMethod(num_samples, data, stat_type):
    monteCarlo_statistics_values = []
    sampled_combinations = [np.random.choice(data.columns, 2, replace=False) for _ in range(num_samples)]
    
    for comb in sampled_combinations:
        i, j = comb
        monteCarlo_statistics_values.append(calculate_statistic_values(data[i], data[j], stat_type))
    
    return monteCarlo_statistics_values



# 计算指定类型的统计量
def calculate_statistic_values(data1, data2, stat_type):
    if stat_type == "ARI":
        return adjusted_rand_score(data1, data2)
    elif stat_type == "NMI":
        return normalized_mutual_info_score(data1, data2)
    elif stat_type == "Kappa":
        return cohen_kappa_score(data1, data2)

# 计算覆盖率
def calculate_coverage(interval1, interval2):
    L1, U1 = interval1
    L2, U2 = interval2
    L_overlap = max(L1, L2)
    U_overlap = min(U1, U2)
    if L_overlap > U_overlap:
        return 0.0
    overlap_length = U_overlap - L_overlap
    length1 = U1 - L1
    coverage = overlap_length / length1
    return coverage
# def calculate_proportion(values, lower_bound, upper_bound):
#     # value
#     return np.sum((values >= lower_bound) & (values <= upper_bound)) / len(values)
def calculate_proportion(values, lower_bound, upper_bound):
    # 确保 values 是一个一维数组或列表
    values = np.asarray(values).flatten()
    
    common_count = 0
    total_count = len(values)
    for value in values:
        if lower_bound <= value <= upper_bound:
            common_count += 1
            
    return common_count / total_count

# 数据加载
data_df = pd.read_csv('repro-out/filtered_data.csv')
filtered_data_repro = data_df[[f'new_Out{i}' for i in range(1, 1001)]]
out0 = data_df['new_Out0']

# 定义要计算的统计量类型
stat_types = ["ARI", "NMI", "Kappa"]  # 可选值："ARI", "NMI", "Kappa"

for stat_type in stat_types:
    print(f"\n计算 {stat_type} 统计量:") 
    # 计算原始结果与复现结果的指定统计量
    real_values = [calculate_statistic_values(out0, filtered_data_repro[f'new_Out{i}'], stat_type) for i in range(1, 1001)]
    # 计算置信区间-----总误差
    ci_low, ci_high = calculate_confidence_interval(real_values)
    # -----随机误差
    monteCarlo_values = monteCarloMethod(10000, filtered_data_repro, stat_type)
    ci_low_mc_random, ci_high_mc_random = calculate_confidence_interval(monteCarlo_values)
    print(f"原始结果与复现结果之间的{stat_type} 95%置信区间: ({ci_low}, {ci_high});随机误差范围: ({ci_low_mc_random}, {ci_high_mc_random})")
    # 计算覆盖率

    ratio_original = calculate_proportion(monteCarlo_values, ci_low, 1)


    coverage = calculate_coverage((ci_low, 1), (ci_low_mc_random, ci_high_mc_random))
    print(f"{stat_type}置信区间覆盖率: {coverage:.2f}；概率{ratio_original}")
    # 绘制覆盖率图

     # 绘制覆盖率的饼图
    fig, ax = plt.subplots()
    labels = ['Coverage', 'Non-coverage']
    sizes = [coverage, 1-coverage]
    colors = ['lightcoral', 'lightskyblue']
    explode = (0.1, 0)  # 突出显示覆盖率
    ax.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
           shadow=True, startangle=140)
    ax.axis('equal')
    plt.title(f'{stat_type} Coverage')
    plt.show()
# Out:
# 计算 ARI 统计量:
# 原始结果与复现结果之间的ARI 95%置信区间: (0.634865798764543, 0.9967794820919688);随机误差范围: (0.5931759704749564, 1.0)
# ARI置信区间覆盖率: 1.00；概率0.761
# 计算 NMI 统计量:
# 原始结果与复现结果之间的NMI 95%置信区间: (0.7048283673584766, 0.9929349545054262);随机误差范围: (0.6799806861485262, 1.0)
# NMI置信区间覆盖率: 1.00；概率0.7674
# 计算 Kappa 统计量:
# 原始结果与复现结果之间的Kappa 95%置信区间: (0.789359973605696, 0.9977583220053872);随机误差范围: (0.7594974246366425, 1.0)
# Kappa置信区间覆盖率: 1.00；概率0.7628

# %%
from sklearn.metrics import (
    adjusted_rand_score, 
    adjusted_mutual_info_score, 
    homogeneity_completeness_v_measure, 
    fowlkes_mallows_score, 
    jaccard_score
)

def calculate_clustering_similarity(true_labels, predicted_labels):
    similarity_measures = {
        "Adjusted Rand Index": adjusted_rand_score,
        "Adjusted Mutual Information": adjusted_mutual_info_score,
        "Homogeneity": lambda x, y: homogeneity_completeness_v_measure(x, y)[0],
        "Completeness": lambda x, y: homogeneity_completeness_v_measure(x, y)[1],
        "V-Measure": lambda x, y: homogeneity_completeness_v_measure(x, y)[2],
        "Fowlkes-Mallows Index": fowlkes_mallows_score,
        "Jaccard Index": lambda x, y: jaccard_score(
            [1 if label == 0 else 0 for label in x], 
            [1 if label == 0 else 0 for label in y]
        )  # Example for binary case, adjust accordingly for multi-class
    }
    
    results = {}
    for measure_name, measure_func in similarity_measures.items():
        results[measure_name] = measure_func(true_labels, predicted_labels)
    
    return results

# 示例聚类标签
labels_true = data["Out0"]
labels_pred = data["Out18"]

# 计算相似性
similarity_results = calculate_clustering_similarity(labels_true, labels_pred)

# 打印结果
for measure, result in similarity_results.items():
    print(f"{measure}: {result}")
# Out:
# Adjusted Rand Index: 0.634865798764543
# Adjusted Mutual Information: 0.7032003266175793
# Homogeneity: 0.709146198281729
# Completeness: 0.7005627988145978
# V-Measure: 0.7048283673584766
# Fowlkes-Mallows Index: 0.7372517486318747
# Jaccard Index: 0.7407407407407407
